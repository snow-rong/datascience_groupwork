# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
data_chaoyang=pd.read_excel("C:\\Users\\雪宝\\Desktop\\bj_house_info第三版（副本）.xlsx",sheet_name="朝阳")
plt.figure(figsize=(12,5))
plt.hist(data_chaoyang["build_area"],bins=100,edgecolor = 'black')
plt.xlabel('area',fontsize=12)
plt.ylabel('mounts',fontsize=12)
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.title('朝阳区二手房面积分布直方图')
plt.show()

# %%
data_haidian=pd.read_excel("C:\\Users\\雪宝\\Desktop\\bj_house_info第三版（副本）.xlsx",sheet_name="海淀")
plt.figure(figsize=(12,5))
plt.hist(data_haidian["build_area"],bins=100,edgecolor = 'black')
plt.xlabel('area',fontsize=12)
plt.ylabel('mounts',fontsize=12)
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.title('海淀区二手房面积分布直方图')
plt.savefig('海淀区二手房面积分布直方图')
plt.show()

# %%
data_dongcheng=pd.read_excel("C:\\Users\\雪宝\\Desktop\\bj_house_info第三版（副本）.xlsx",sheet_name="东城")
plt.figure(figsize=(12,5))
plt.hist(data_dongcheng["build_area"],bins=100,edgecolor = 'black')
plt.xlabel('area',fontsize=12)
plt.ylabel('mounts',fontsize=12)
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.title('东城区二手房面积分布直方图')
plt.savefig('东城区二手房面积分布直方图')
plt.show()

# %%
data_xicheng=pd.read_excel("C:\\Users\\雪宝\\Desktop\\bj_house_info第三版（副本）.xlsx",sheet_name="西城")
plt.figure(figsize=(12,5))
plt.hist(data_xicheng["build_area"],bins=100,edgecolor = 'black')
plt.xlabel('area',fontsize=12)
plt.ylabel('mounts',fontsize=12)
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.title('西城区二手房面积分布直方图')
plt.show()

# %%
data_fengtai=pd.read_excel("C:\\Users\\雪宝\\Desktop\\bj_house_info第三版（副本）.xlsx",sheet_name="丰台")
plt.figure(figsize=(12,5))
plt.hist(data_fengtai["build_area"],bins=100,edgecolor = 'black')
plt.xlabel('area',fontsize=12)
plt.ylabel('mounts',fontsize=12)
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.title('丰台区二手房面积分布直方图')
plt.show()

# %%
data_tongzhou=pd.read_excel("C:\\Users\\雪宝\\Desktop\\bj_house_info第三版（副本）.xlsx",sheet_name="通州")
plt.figure(figsize=(12,5))
plt.hist(data_tongzhou["build_area"],bins=100,edgecolor = 'black')
plt.xlabel('area',fontsize=12)
plt.ylabel('mounts',fontsize=12)
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.title('通州区二手房面积分布直方图')
plt.show()

# %%
data_shijingshan=pd.read_excel("C:\\Users\\雪宝\\Desktop\\bj_house_info第三版（副本）.xlsx",sheet_name="石景山")
plt.figure(figsize=(12,5))
plt.hist(data_shijingshan["build_area"],bins=100,edgecolor = 'black')
plt.xlabel('area',fontsize=12)
plt.ylabel('mounts',fontsize=12)
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.title('石景山二手房面积分布直方图')
plt.show()

# %%
data_changping=pd.read_excel("C:\\Users\\雪宝\\Desktop\\bj_house_info第三版（副本）.xlsx",sheet_name="昌平")
plt.figure(figsize=(12,5))
plt.hist(data_changping["build_area"],bins=100,edgecolor = 'black')
plt.xlabel('area',fontsize=12)
plt.ylabel('mounts',fontsize=12)
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.title('昌平区二手房面积分布直方图')
plt.show()

# %%
data_daxing=pd.read_excel("C:\\Users\\雪宝\\Desktop\\bj_house_info第三版（副本）.xlsx",sheet_name="大兴")
plt.figure(figsize=(12,5))
plt.hist(data_daxing["build_area"],bins=100,edgecolor = 'black')
plt.xlabel('area',fontsize=12)
plt.ylabel('mounts',fontsize=12)
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.title('大兴区二手房面积分布直方图')
plt.show()

# %%
data_shunyi=pd.read_excel("C:\\Users\\雪宝\\Desktop\\bj_house_info第三版（副本）.xlsx",sheet_name="顺义")
plt.figure(figsize=(12,5))
plt.hist(data_shunyi["build_area"],bins=100,edgecolor = 'black')
plt.xlabel('area',fontsize=12)
plt.ylabel('mounts',fontsize=12)
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.title('顺义区二手房面积分布直方图')
plt.show()

# %%
data_fangshan=pd.read_excel("C:\\Users\\雪宝\\Desktop\\bj_house_info第三版（副本）.xlsx",sheet_name="房山")
plt.figure(figsize=(12,5))
plt.hist(data_fangshan["build_area"],bins=100,edgecolor = 'black')
plt.xlabel('area',fontsize=12)
plt.ylabel('mounts',fontsize=12)
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.title('房山区二手房面积分布直方图')
plt.show()

# %%
data_mentougou=pd.read_excel("C:\\Users\\雪宝\\Desktop\\bj_house_info第三版（副本）.xlsx",sheet_name="门头沟")
plt.figure(figsize=(12,5))
plt.hist(data_mentougou["build_area"],bins=100,edgecolor = 'black')
plt.xlabel('area',fontsize=12)
plt.ylabel('mounts',fontsize=12)
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.title('门头沟二手房面积分布直方图')
plt.show()

# %%
data_miyun=pd.read_excel("C:\\Users\\雪宝\\Desktop\\bj_house_info第三版（副本）.xlsx",sheet_name="密云")
plt.figure(figsize=(12,5))
plt.hist(data_miyun["build_area"],bins=100,edgecolor = 'black')
plt.xlabel('area',fontsize=12)
plt.ylabel('mounts',fontsize=12)
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.title('密云区二手房面积分布直方图')
plt.show()

# %%
data_huairou=pd.read_excel("C:\\Users\\雪宝\\Desktop\\bj_house_info第三版（副本）.xlsx",sheet_name="怀柔")
plt.figure(figsize=(12,5))
plt.hist(data_huairou["build_area"],bins=100,edgecolor = 'black')
plt.xlabel('area',fontsize=12)
plt.ylabel('mounts',fontsize=12)
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.title('怀柔区二手房面积分布直方图')
plt.show()

# %%
data_pinggu=pd.read_excel("C:\\Users\\雪宝\\Desktop\\bj_house_info第三版（副本）.xlsx",sheet_name="平谷")
plt.figure(figsize=(12,5))
plt.hist(data_pinggu["build_area"],bins=100,edgecolor = 'black')
plt.xlabel('area',fontsize=12)
plt.ylabel('mounts',fontsize=12)
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.title('平谷区二手房面积分布直方图')
plt.show()

# %%
data_yanqing=pd.read_excel("C:\\Users\\雪宝\\Desktop\\bj_house_info第三版（副本）.xlsx",sheet_name="延庆")
plt.figure(figsize=(12,5))
plt.hist(data_yanqing["build_area"],bins=100,edgecolor = 'black')
plt.xlabel('area',fontsize=12)
plt.ylabel('mounts',fontsize=12)
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.title('延庆区二手房面积分布直方图')
plt.show()

# %%
data_zhoubian=pd.read_excel("C:\\Users\\雪宝\\Desktop\\bj_house_info第三版（副本）.xlsx",sheet_name="北京周边")
plt.figure(figsize=(12,5))
plt.hist(data_zhoubian["build_area"],bins=100,edgecolor = 'black')
plt.xlabel('area',fontsize=12)
plt.ylabel('mounts',fontsize=12)
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.title('北京周边二手房面积分布直方图')
plt.show()
